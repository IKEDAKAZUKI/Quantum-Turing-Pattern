# %% [markdown]
# # Quantum Turing Patterns — Portable Explorer
#
# Use this notebook to explore the three reference patterns, follow their time evolution, and save selected results with the information needed to reproduce them.
#
# This notebook uses a standard Python kernel. If interactive controls are unavailable, it runs a preview with the default settings in a regular notebook cell.

# %%
from qtp_notebook_app import show_research_app

show_research_app()
