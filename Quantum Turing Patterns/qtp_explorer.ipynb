# %% [markdown]
# # Quantum Turing Patterns — Research Explorer
#
# Use the controls below to vary the initial conditions, inspect the time evolution, and save selected results.
#
# The museum exhibit is available in `qtp_exhibit.ipynb`.

# %%
from qtp_notebook_app import show_research_app

show_research_app()
